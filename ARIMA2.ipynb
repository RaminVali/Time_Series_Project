# %% [markdown]
# # This is the kaggle dataset. Why is it different with respect to seasonality? Best is to compare both of them.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import fredapi 
#import yfinance as yf
import datetime
import seaborn as sns
import random
from statsmodels.tsa.seasonal import seasonal_decompose
import json
import plotly.express as px
import plotly.graph_objects as go

# %%
data = pd.read_csv('macro_monthly.csv')
df = data[['DATE','ccpi']].copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    490 non-null    object
#  1   ccpi    490 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.8+ KB

# %%
df['DATE'] = pd.to_datetime(df['DATE'])
df.set_index('DATE', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 490 entries, 1981-01-01 to 2021-10-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ccpi    490 non-null    float64
# dtypes: float64(1)
# memory usage: 7.7 KB

# %%
df.head()
# Out:
#             ccpi
# DATE
# 1981-01-01  85.4
# 1981-02-01  85.9
# 1981-03-01  86.4
# 1981-04-01  87.0
# 1981-05-01  87.8

# %%
df.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
fig = seasonal_decompose(df['ccpi'], model='additive').plot()
