# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
MSFT = yf.Ticker("MSFT")
print(MSFT.info)
# Out:
# {'symbol': 'MSFT', 'twoHundredDayAverageChangePercent': 0.1479931, 'dividendDate': 1686182400, 'averageAnalystRating': '1.9 - Buy', 'fiftyTwoWeekLowChangePercent': 0.366256, 'language': 'en-US', 'earningsTimestampEnd': 1682683200, 'regularMarketDayRange': '282.03 - 292.08', 'epsForward': 10.75, 'regularMarketDayHigh': 292.08, 'twoHundredDayAverageChange': 37.591507, 'askSize': 10, 'twoHundredDayAverage': 254.0085, 'bookValue': 24.592, 'fiftyTwoWeekHighChange': -9.519989, 'marketCap': 2170612088832, 'fiftyTwoWeekRange': '213.43 - 301.12', 'fiftyDayAverageChange': 27.472809, 'exchangeDataDelayedBy': 0, 'firstTradeDateMilliseconds': 511108200000, 'averageDailyVolume3Month': 31808980, 'trailingAnnualDividendRate': 2.6, 'fiftyTwoWeekLow': 213.43, 'regularMarketVolume': 29770334, 'market': 'us_market', 'postMarketPrice': 291.6, 'quoteSourceName': 'Delayed Quote', 'messageBoardId': 'finmb_21835', 'priceHint': 2, 'regularMarketDayLow': 282.03, 'sourceInterval': 15, 'exchange': 'NMS', 'shortName': 'Microsoft Corporation', 'region': 'US', 'fiftyDayAverageChangePercent': 0.104013555, 'fullExchangeName': 'NasdaqGS', 'earningsTimestampStart': 1682333940, 'financialCurrency': 'USD', 'displayName': 'Microsoft', 'gmtOffSetMilliseconds': -14400000, 'regularMarketOpen': 283.21, 'regularMarketTime': '4:00PM EDT', 'regularMarketChangePercent': 2.5532846, 'trailingAnnualDividendYield': 0.009143982, 'quoteType': 'EQUITY', 'averageDailyVolume10Day': 26227860, 'fiftyTwoWeekLowChange': 78.17001, 'fiftyTwoWeekHighChangePercent': -0.03161527, 'typeDisp': 'Equity', 'trailingPE': 31.558443, 'tradeable': False, 'postMarketTime': '7:59PM EDT', 'currency': 'USD', 'sharesOutstanding': 7443800064, 'regularMarketPreviousClose': 284.34, 'fiftyTwoWeekHigh': 301.12, 'postMarketChangePercent': 0.0, 'exchangeTimezoneName': 'America/New_York', 'regularMarketChange': 7.26001, 'bidSize': 10, 'priceEpsCurrentYear': 31.153849, 'cryptoTradeable': False, 'fiftyDayAverage': 264.1272, 'epsCurrentYear': 9.36, 'exchangeTimezoneShortName': 'EDT', 'customPriceAlertConfidence': 'HIGH', 'marketState': 'CLOSED', 'regularMarketPrice': 291.6, 'forwardPE': 27.125582, 'postMarketChange': 0.0, 'earningsTimestamp': 1674599400, 'ask': 291.95, 'epsTrailingTwelveMonths': 9.24, 'bid': 291.5, 'triggerable': True, 'priceToBook': 11.857515, 'longName': 'Microsoft Corporation', 'trailingPegRatio': 2.1346}

# %%
MSFT = MSFT.history(period = '30y') # period = 'max' did not work gives no data, but this works
MSFT.to_csv('MSFT.csv')
MSFT = MSFT['Close']

# %%
MSFT.index = pd.to_datetime(MSFT.index).tz_localize(None)
MSFT.index
# Out:
# DatetimeIndex(['1993-04-07', '1993-04-08', '1993-04-12', '1993-04-13',
#                '1993-04-14', '1993-04-15', '1993-04-16', '1993-04-19',
#                '1993-04-20', '1993-04-21',
#                ...
#                '2023-03-24', '2023-03-27', '2023-03-28', '2023-03-29',
#                '2023-03-30', '2023-03-31', '2023-04-03', '2023-04-04',
#                '2023-04-05', '2023-04-06'],
#               dtype='datetime64[ns]', name='Date', length=7555, freq=None)

# %%
MSFT.plot(y='Close', title = "MSFT closing prices")
# Out:
# <Axes: title={'center': 'MSFT closing prices'}, xlabel='Date'>

# %% [markdown]
# Need to convert this probelm into a supervised learning problem

# %%
df = MSFT.copy()
df = pd.DataFrame(df, index=df.index)
df.rename(columns={'Close':'Target'}, inplace=True)

# %%
def df_to_windowed_df (dataframe, first_date_str, last_date_str, n = 3):
  first_date =  pd.to_datetime(first_date_str)
  last_date  =  pd.to_datetime(last_date_str)

  for a in range(1,n+1):
    df[f'Target-{a}'] = df['Target'].shift(a)
  
  return df[(df.index>=first_date)&(df.index<=last_date)].dropna()

# %%
windowed_df = df_to_windowed_df(df, '1986-03-25', '2023-03-23', 3) 
windowed_df['Target Date'] = windowed_df.index

# %% [markdown]
# Just using the lagging closing values as input to the model. the "Target" column is the closing value on the actual date.

# %% [markdown]
# Changing into a numpy array. We make a function with three hourputs, X: 3D tesnsor with the input data, y is the target coloumn and Date is the date coloumn

# %%
windowed_df.head()
# Out:
#               Target  Target-1  Target-2  Target-3 Target Date
# Date
# 1993-04-13  1.732780  1.757151  1.735217  1.759589  1993-04-13
# 1993-04-14  1.735217  1.732780  1.757151  1.735217  1993-04-14
# 1993-04-15  1.698660  1.735217  1.732780  1.757151  1993-04-15
# 1993-04-16  1.696223  1.698660  1.735217  1.732780  1993-04-16
# 1993-04-19  1.696223  1.696223  1.698660  1.735217  1993-04-19

# %%
def windowed_df_to_date_X_y(windwed_df):
  df_as_np = windwed_df.to_numpy()

  dates = df_as_np[:,-1] #grabbing the target date column

  middle = df_as_np[:,1:-1]
  X = middle.reshape((len(dates), middle.shape[1],1)) # reshaping to add to Keras, using 1 variable, so 1 at the end, and first dimention is the length of the dates. second dimention is the columns
  y = df_as_np[:,0] # Get the target column

  return dates, X.astype(np.float32), y.astype(np.float32) #changing type for Keras

# %%
dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((7542,), (7542, 3, 1), (7542,))

# %% [markdown]
# Note the shapes, This is what we wanted in terms of the dimentioning for Keras. So take home point< make sure the shapes of your X,y are correct for feeding into Keras, and the types have to be float32.

# %%
q_80 = int(len(dates) * 0.8) #setting up test, validation and train indexes. 
q_90 = int(len(dates) * 0.9)

# setting up train, validation and test sets

X_train = X[:q_80]
y_train = y[:q_80]
dates_train = dates[:q_80]

X_val = X[q_80:q_90]
y_val = y[q_80:q_90]
dates_val = dates[q_80:q_90]

X_test = X[q_90:]
y_test = y[q_90:]
dates_test = dates[q_90:]

# %%
plt.plot(dates_train,y_train)
plt.plot(dates_val,y_val)
plt.plot(dates_test,y_test)

plt.legend(['train','validation','test'])
plt.xticks(rotation=45);

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers


model = Sequential([layers.Input((3,1)), # 3 days in the past, and we only use 1 feature.
                    layers.LSTM(64), # the larger the number, its heavier, more prone to be overfitting and more connections
                    layers.Dense(32, activation = 'relu'),
                    layers.Dense(32, activation = 'relu'),
                    layers.Dense(1)]) # 1 because we are predicting only 1 variable.

model.compile(loss = 'mse', #mean squared error
              optimizer = Adam(learning_rate = 0.001),
              metrics = ['mean_absolute_error'])

model.fit(X_train,y_train, validation_data =(X_val, y_val), epochs = 100)
# Out:
# Epoch 1/100
# 189/189 [==============================] - 4s 7ms/step - loss: 144.8970 - mean_absolute_error: 6.7366 - val_loss: 3439.5173 - val_mean_absolute_error: 50.6376
# Epoch 2/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.7406 - mean_absolute_error: 0.5554 - val_loss: 2812.0679 - val_mean_absolute_error: 44.1536
# Epoch 3/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.5528 - mean_absolute_error: 0.5020 - val_loss: 2667.7827 - val_mean_absolute_error: 42.4802
# Epoch 4/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.4658 - mean_absolute_error: 0.4497 - val_loss: 2592.4746 - val_mean_absolute_error: 41.5754
# Epoch 5/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.4535 - mean_absolute_error: 0.4538 - val_loss: 2571.5266 - val_mean_absolute_error: 41.1624
# Epoch 6/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.4119 - mean_absolute_error: 0.4246 - val_loss: 2577.3899 - val_mean_absolute_error: 41.1995
# Epoch 7/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.3693 - mean_absolute_error: 0.4033 - val_loss: 2568.3672 - val_mean_absolute_error: 40.9406
# Epoch 8/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.3289 - mean_absolute_error: 0.3758 - val_loss: 2587.0940 - val_mean_absolute_error: 40.7540
# Epoch 9/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.3350 - mean_absolute_error: 0.3778 - val_loss: 2620.9661 - val_mean_absolute_error: 41.0056
# Epoch 10/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.3266 - mean_absolute_error: 0.3762 - val_loss: 2649.7598 - val_mean_absolute_error: 41.1889
# Epoch 11/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.3348 - mean_absolute_error: 0.3904 - val_loss: 2719.0222 - val_mean_absolute_error: 41.6101
# Epoch 12/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2788 - mean_absolute_error: 0.3418 - val_loss: 2744.3008 - val_mean_absolute_error: 41.6577
# Epoch 13/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.3097 - mean_absolute_error: 0.3707 - val_loss: 2792.1428 - val_mean_absolute_error: 41.9463
# Epoch 14/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2921 - mean_absolute_error: 0.3597 - val_loss: 2838.2395 - val_mean_absolute_error: 42.2676
# Epoch 15/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2789 - mean_absolute_error: 0.3480 - val_loss: 2867.5173 - val_mean_absolute_error: 42.4764
# Epoch 16/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2719 - mean_absolute_error: 0.3456 - val_loss: 2879.4248 - val_mean_absolute_error: 42.5108
# Epoch 17/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2652 - mean_absolute_error: 0.3353 - val_loss: 2892.9287 - val_mean_absolute_error: 42.5490
# Epoch 18/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2778 - mean_absolute_error: 0.3497 - val_loss: 2957.6873 - val_mean_absolute_error: 43.0076
# Epoch 19/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2689 - mean_absolute_error: 0.3438 - val_loss: 2965.9084 - val_mean_absolute_error: 43.1367
# Epoch 20/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2794 - mean_absolute_error: 0.3560 - val_loss: 3048.0879 - val_mean_absolute_error: 43.6292
# Epoch 21/100
# 189/189 [==============================] - 1s 3ms/step - loss: 0.2604 - mean_absolute_error: 0.3346 - val_loss: 3070.8474 - val_mean_absolute_error: 43.8988
# Epoch 22/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2717 - mean_absolute_error: 0.3495 - val_loss: 3085.7725 - val_mean_absolute_error: 44.1031
# Epoch 23/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2703 - mean_absolute_error: 0.3460 - val_loss: 3121.2197 - val_mean_absolute_error: 44.1281
# Epoch 24/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2697 - mean_absolute_error: 0.3453 - val_loss: 3124.8416 - val_mean_absolute_error: 44.1837
# Epoch 25/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2562 - mean_absolute_error: 0.3332 - val_loss: 3126.3389 - val_mean_absolute_error: 44.2173
# Epoch 26/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2544 - mean_absolute_error: 0.3320 - val_loss: 3137.0322 - val_mean_absolute_error: 44.1918
# Epoch 27/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.3062 - mean_absolute_error: 0.3790 - val_loss: 3183.1604 - val_mean_absolute_error: 44.5079
# Epoch 28/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2477 - mean_absolute_error: 0.3304 - val_loss: 3154.9668 - val_mean_absolute_error: 44.3458
# Epoch 29/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2745 - mean_absolute_error: 0.3482 - val_loss: 3170.0808 - val_mean_absolute_error: 44.3501
# Epoch 30/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2783 - mean_absolute_error: 0.3575 - val_loss: 3171.1990 - val_mean_absolute_error: 44.4215
# Epoch 31/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2644 - mean_absolute_error: 0.3465 - val_loss: 3228.8066 - val_mean_absolute_error: 44.8134
# Epoch 32/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2471 - mean_absolute_error: 0.3318 - val_loss: 3219.5862 - val_mean_absolute_error: 44.7984
# Epoch 33/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2457 - mean_absolute_error: 0.3298 - val_loss: 3183.9243 - val_mean_absolute_error: 44.5475
# Epoch 34/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2545 - mean_absolute_error: 0.3383 - val_loss: 3185.4333 - val_mean_absolute_error: 44.3952
# Epoch 35/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2371 - mean_absolute_error: 0.3201 - val_loss: 3209.1824 - val_mean_absolute_error: 44.6347
# Epoch 36/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2702 - mean_absolute_error: 0.3521 - val_loss: 3268.0703 - val_mean_absolute_error: 45.1069
# Epoch 37/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2705 - mean_absolute_error: 0.3459 - val_loss: 3265.0166 - val_mean_absolute_error: 45.2614
# Epoch 38/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2383 - mean_absolute_error: 0.3225 - val_loss: 3244.7000 - val_mean_absolute_error: 44.8693
# Epoch 39/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2420 - mean_absolute_error: 0.3276 - val_loss: 3272.4387 - val_mean_absolute_error: 45.2307
# Epoch 40/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2511 - mean_absolute_error: 0.3385 - val_loss: 3314.5823 - val_mean_absolute_error: 45.4063
# Epoch 41/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2315 - mean_absolute_error: 0.3157 - val_loss: 3273.9951 - val_mean_absolute_error: 45.1414
# Epoch 42/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2568 - mean_absolute_error: 0.3422 - val_loss: 3282.6924 - val_mean_absolute_error: 45.3730
# Epoch 43/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2417 - mean_absolute_error: 0.3268 - val_loss: 3268.2698 - val_mean_absolute_error: 45.1232
# Epoch 44/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2345 - mean_absolute_error: 0.3203 - val_loss: 3230.3901 - val_mean_absolute_error: 44.7375
# Epoch 45/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2410 - mean_absolute_error: 0.3246 - val_loss: 3213.8003 - val_mean_absolute_error: 44.4231
# Epoch 46/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2806 - mean_absolute_error: 0.3652 - val_loss: 3251.8445 - val_mean_absolute_error: 44.9992
# Epoch 47/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2379 - mean_absolute_error: 0.3232 - val_loss: 3212.6582 - val_mean_absolute_error: 44.4569
# Epoch 48/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2343 - mean_absolute_error: 0.3189 - val_loss: 3221.6130 - val_mean_absolute_error: 44.7445
# Epoch 49/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2420 - mean_absolute_error: 0.3224 - val_loss: 3257.4712 - val_mean_absolute_error: 45.0540
# Epoch 50/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2385 - mean_absolute_error: 0.3281 - val_loss: 3259.1511 - val_mean_absolute_error: 45.1270
# Epoch 51/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2345 - mean_absolute_error: 0.3206 - val_loss: 3220.7878 - val_mean_absolute_error: 44.6406
# Epoch 52/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2337 - mean_absolute_error: 0.3179 - val_loss: 3256.8892 - val_mean_absolute_error: 45.0107
# Epoch 53/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2464 - mean_absolute_error: 0.3315 - val_loss: 3276.2537 - val_mean_absolute_error: 45.1781
# Epoch 54/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2537 - mean_absolute_error: 0.3431 - val_loss: 3253.7427 - val_mean_absolute_error: 44.9880
# Epoch 55/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2392 - mean_absolute_error: 0.3260 - val_loss: 3217.3999 - val_mean_absolute_error: 44.6385
# Epoch 56/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2369 - mean_absolute_error: 0.3218 - val_loss: 3235.2688 - val_mean_absolute_error: 44.7674
# Epoch 57/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2635 - mean_absolute_error: 0.3410 - val_loss: 3203.0386 - val_mean_absolute_error: 44.5961
# Epoch 58/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2273 - mean_absolute_error: 0.3150 - val_loss: 3241.5073 - val_mean_absolute_error: 44.8484
# Epoch 59/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.2608 - mean_absolute_error: 0.3493 - val_loss: 3255.5547 - val_mean_absolute_error: 45.0698
# Epoch 60/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2590 - mean_absolute_error: 0.3439 - val_loss: 3227.0103 - val_mean_absolute_error: 44.8547
# Epoch 61/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2380 - mean_absolute_error: 0.3232 - val_loss: 3221.6184 - val_mean_absolute_error: 44.7317
# Epoch 62/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2439 - mean_absolute_error: 0.3255 - val_loss: 3164.5500 - val_mean_absolute_error: 44.1136
# Epoch 63/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2365 - mean_absolute_error: 0.3234 - val_loss: 3188.0972 - val_mean_absolute_error: 44.3038
# Epoch 64/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2448 - mean_absolute_error: 0.3284 - val_loss: 3233.3435 - val_mean_absolute_error: 44.8679
# Epoch 65/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2362 - mean_absolute_error: 0.3226 - val_loss: 3257.8142 - val_mean_absolute_error: 45.0727
# Epoch 66/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2645 - mean_absolute_error: 0.3440 - val_loss: 3234.2622 - val_mean_absolute_error: 44.8661
# Epoch 67/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2400 - mean_absolute_error: 0.3194 - val_loss: 3261.1047 - val_mean_absolute_error: 45.1121
# Epoch 68/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2497 - mean_absolute_error: 0.3385 - val_loss: 3255.1543 - val_mean_absolute_error: 45.0257
# Epoch 69/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2462 - mean_absolute_error: 0.3310 - val_loss: 3217.0132 - val_mean_absolute_error: 44.6004
# Epoch 70/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2262 - mean_absolute_error: 0.3103 - val_loss: 3201.0239 - val_mean_absolute_error: 44.5035
# Epoch 71/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2319 - mean_absolute_error: 0.3214 - val_loss: 3262.9265 - val_mean_absolute_error: 45.2134
# Epoch 72/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2344 - mean_absolute_error: 0.3226 - val_loss: 3235.1372 - val_mean_absolute_error: 44.8824
# Epoch 73/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2256 - mean_absolute_error: 0.3133 - val_loss: 3252.3499 - val_mean_absolute_error: 44.9499
# Epoch 74/100
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2468 - mean_absolute_error: 0.3366 - val_loss: 3167.6409 - val_mean_absolute_error: 44.1837
# Epoch 75/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2143 - mean_absolute_error: 0.3042 - val_loss: 3215.9729 - val_mean_absolute_error: 44.6769
# Epoch 76/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2311 - mean_absolute_error: 0.3212 - val_loss: 3265.5889 - val_mean_absolute_error: 45.0984
# Epoch 77/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2601 - mean_absolute_error: 0.3428 - val_loss: 3278.8962 - val_mean_absolute_error: 45.2104
# Epoch 78/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2322 - mean_absolute_error: 0.3241 - val_loss: 3236.6660 - val_mean_absolute_error: 44.8296
# Epoch 79/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2402 - mean_absolute_error: 0.3308 - val_loss: 3262.3630 - val_mean_absolute_error: 45.1223
# Epoch 80/100
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2749 - mean_absolute_error: 0.3491 - val_loss: 3233.5601 - val_mean_absolute_error: 44.8711
# Epoch 81/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2223 - mean_absolute_error: 0.3121 - val_loss: 3278.5669 - val_mean_absolute_error: 45.3227
# Epoch 82/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2345 - mean_absolute_error: 0.3220 - val_loss: 3270.8086 - val_mean_absolute_error: 45.2958
# Epoch 83/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2294 - mean_absolute_error: 0.3166 - val_loss: 3298.5308 - val_mean_absolute_error: 45.5789
# Epoch 84/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2362 - mean_absolute_error: 0.3200 - val_loss: 3263.2207 - val_mean_absolute_error: 45.1220
# Epoch 85/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2302 - mean_absolute_error: 0.3160 - val_loss: 3283.7295 - val_mean_absolute_error: 45.5257
# Epoch 86/100
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2364 - mean_absolute_error: 0.3246 - val_loss: 3273.7712 - val_mean_absolute_error: 45.1723
# Epoch 87/100
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2294 - mean_absolute_error: 0.3164 - val_loss: 3284.5637 - val_mean_absolute_error: 45.3818
# Epoch 88/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2325 - mean_absolute_error: 0.3194 - val_loss: 3289.3076 - val_mean_absolute_error: 45.3655
# Epoch 89/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2268 - mean_absolute_error: 0.3161 - val_loss: 3241.7910 - val_mean_absolute_error: 44.8870
# Epoch 90/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2573 - mean_absolute_error: 0.3422 - val_loss: 3304.3591 - val_mean_absolute_error: 45.6196
# Epoch 91/100
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2264 - mean_absolute_error: 0.3156 - val_loss: 3290.9651 - val_mean_absolute_error: 45.4526
# Epoch 92/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2278 - mean_absolute_error: 0.3128 - val_loss: 3268.2854 - val_mean_absolute_error: 45.2227
# Epoch 93/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2599 - mean_absolute_error: 0.3449 - val_loss: 3302.1196 - val_mean_absolute_error: 45.5698
# Epoch 94/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2435 - mean_absolute_error: 0.3299 - val_loss: 3263.8730 - val_mean_absolute_error: 45.1495
# Epoch 95/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2422 - mean_absolute_error: 0.3274 - val_loss: 3262.8877 - val_mean_absolute_error: 45.0784
# Epoch 96/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2561 - mean_absolute_error: 0.3427 - val_loss: 3299.7722 - val_mean_absolute_error: 45.4000
# Epoch 97/100
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2247 - mean_absolute_error: 0.3097 - val_loss: 3280.2349 - val_mean_absolute_error: 45.2883
# Epoch 98/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.2319 - mean_absolute_error: 0.3195 - val_loss: 3316.5334 - val_mean_absolute_error: 45.6189
# Epoch 99/100
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2254 - mean_absolute_error: 0.3120 - val_loss: 3276.5242 - val_mean_absolute_error: 45.2676
# Epoch 100/100
# 189/189 [==============================] - 1s 6ms/step - loss: 0.2248 - mean_absolute_error: 0.3124 - val_loss: 3281.6138 - val_mean_absolute_error: 45.2955

# %%
train_predictions = model.predict(X_train).flatten() # note the flatten

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
plt.xticks(rotation=45);
# Out:
# 189/189 [==============================] - 1s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
plt.xticks(rotation=45);
# Out:
# 24/24 [==============================] - 0s 2ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
plt.xticks(rotation=45);
# Out:
# 24/24 [==============================] - 0s 2ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])
plt.xticks(rotation=45);

# %% [markdown]
# LSTM models are very bad at extrapolating, it will not predict well if the values are outside of its range.
#
# So you have to make sure to train on the last parts. Les see if you give it ALL the historical data:

# %%
plt.plot(dates_train,y_train)
plt.plot(dates_val,y_val)
plt.plot(dates_test,y_test)

plt.legend(['train','validation','test'])
plt.xticks(rotation=45);

# %%
val_predictions = model.predict(X_val).flatten()
train_predictions = model.predict(X_train).flatten() # note the flatten
test_predictions = model.predict(X_test).flatten()
# Out:
# 24/24 [==============================] - 0s 2ms/step
# 189/189 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])
plt.xticks(rotation=45);

# %% [markdown]
# Notice how bad it is in following the trend.
